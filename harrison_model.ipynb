# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import math
import scipy.io as sio
from pathlib import Path

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Fmri data

# %%
NUM_SUBJS = 8
subjects_fmri = [] #stores all 8 subject fmri np arrays

fMRI_folder = Path('./doi_10.5061_dryad.gt413__v1')
assert fMRI_folder.exists(), f"Foldder: {fMRI_folder} does not exist."

for subj_id in range(8):
    fmri_file_name = str(subj_id) + '_masked_2d.npy'
    fmri = np.load(fMRI_folder / fmri_file_name)
    assert isinstance(fmri, np.ndarray), f"Imported fmri_scan for subject {subj_id} is not of type numpy.ndarray"
    assert(fmri.ndim) == 2, f"Imported fmri_scan for subject {subj_id} is not 2 dimensional"
    subjects_fmri.append(fmri)

# %% [markdown]
# ### Word features

# %%
feature_matrix = np.zeros((5176,195)) #stores the feature vectors as a row for each word
feature_names = [] #stores the names of all features in order
feature_types = {} #stores the types of features and all the names of the features for each type

features = sio.loadmat(fMRI_folder / 'story_features.mat')
feature_count = 0
for feature_type in features['features'][0]:
    feature_types[feature_type[0][0]] = []
    if isinstance(feature_type[1][0], str):
        feature_types[feature_type[0][0]].append(feature_type[1][0])
        feature_names.append(feature_type[1][0])
    else:
        for feature in feature_type[1][0]:
            feature_types[feature_type[0][0]].append(feature[0])
            feature_names.append(feature[0])
    feature_matrix[:, feature_count:feature_count+feature_type[2].shape[1]] = feature_type[2] #adds the (5176xN) feature values to the feature matrix for the current feature group
    feature_count += feature_type[2].shape[1]

# %% [markdown]
# ### Word values and timings

# %%
words_info = [] #stores tuples of (word, time, features) sorted by time appeared

mat_file = fMRI_folder / 'subject_1.mat' #only looks at the first subject file, somewhere it said all the timings were the same so this should be safe
mat_contents = sio.loadmat(mat_file)
for count, row in enumerate(mat_contents['words'][0]):
    word_value = row[0][0][0][0]
    time = row[1][0][0]
    word_tuple = (word_value, time, feature_matrix[count,:])
    words_info.append(word_tuple)

# %% [markdown]
# ## Align fmri and word features

# %% [markdown]
# Still working on this part - Harrison

# %%
#class for storing all the information for each sample

class sample: 
    def __init__(self, subj_id, time, input_voxels, output_voxels, input_words, input_word_features, output_words, output_word_features):
        self.subj_id = subj_id #id of subject
        
        self.time = time #time at which the scan occurred
        
        assert input_voxels.shape[0] == 4, "input_voxels does not contain 4 scans"
        self.input_voxels = input_voxels #2d array of 4 TRs of voxels at time of scan
        
        assert output_voxels.shape[0] == 4, "output_voxels does not contain 4 scans"
        self.output_voxels = output_voxels #2d array of 4 TRs of voxels associated with next 4 words
        
        assert len(input_words) == 4, "input_words does not contain 4 words"
        self.input_words = input_words #list of 4 words associated with scan
        
        assert len(output_words) == 4, "output_words does not contain 4 words"
        self.output_words = output_words #list of 4 words that come after scan
        
        assert input_word_features.shape[0] == 4, "input_word_features does not contain 4 words"
        self.input_word_features = input_word_features #np array of size (4,nFeatures) storing the features for the 4 words
        
        assert output_word_features.shape[0] == 4, "output_word_features does not contain 4 words"
        self.output_word_features = output_word_features #np array of size (4,nFeatures) storing the features for the 4 words afterwards
    
    def get_subj_id(self):
        return self.subj_id
    
    def get_time(self):
        return self.time
    
    def get_input_voxels(self):
        return self.input_voxels
    
    def get_output_voxels(self):
        return self.output_voxels
    
    def get_input_words(self):
        return self.input_words
    
    def get_input_word_features(self):
        return self.input_word_features
    
    def get_output_words(self):
        return self.output_words
    
    def get_output_word_features(self):
        return self.output_word_features

# %%
subjects_samples = [[] for i in range(NUM_SUBJS)] #stores lists of all the samples for each subject

#still working on this, need to deal with the issue where a rest happens 
word_count = 0
while word_count < len(words_info) - 8:
    #gets the 4 input words, and the 4 consecutive words while verifying they were read in sequence
    scan_words = []
    start_time = words_info[word_count][1]
    in_sequence = True #tracks if the words are in sequence or not
    for i in range(8):
        word_info = words_info[word_count + i]
        if word_info[1] != start_time + 0.5*i:
            #if some of the words are not in sequence, skip forward 1 word after innter loop
            in_sequence = False
        scan_words.append(word_info[0])
    if not in_sequence:
        word_count +=1
        continue
    #gets word features for input and output words
    input_word_features = feature_matrix[word_count:word_count+4, :]
    output_word_features = feature_matrix[word_count+4:word_count+8,:]
    #gets index of fmri that comes 2 seconds after reading first word
    fmri_time = start_time + 2 #effect of reading words is assumed to start 2 seconds after and end 8 seconds after
    fmri_index = fmri_time//2 #since a scan happens every two seconds, the index is the time divided by 2
    if not isinstance(fmri_index, np.int32):
        #if the first word is not aligned with the fmri scan (i.e. its not the first word in a TR)
        word_count += 1
        continue
    for count, subject in enumerate(subjects_fmri):
        new_sample = sample(count, 
                            start_time, 
                            subject[fmri_index:fmri_index+4,:], #gets the scans 2,4,6,8 seconds after reading
                            subject[fmri_index+2:fmri_index+6,:], #gets the scans 4,6,8,10 seconds after reading
                            scan_words[0:4], 
                            input_word_features,
                            scan_words[4:8],
                            output_word_features)
        subjects_samples[count].append(new_sample)
    print("Created sample:")
    print("\tScan time:", str(start_time))
    print("\tInput words:", str(scan_words[0:4]))
    print("\tOutput_words", str(scan_words[4:8]))
    #if successful, skip forward to the next set of 4 words
    word_count += 4

print("Total number of samples:", str(len(subjects_samples[0])))
# Out:
# Created sample:
# 	Scan time: 20
# 	Input words: ['Harry', 'had', 'never', 'believed']
# 	Output_words ['he', 'would', 'meet', 'a']
# Created sample:
# 	Scan time: 22
# 	Input words: ['he', 'would', 'meet', 'a']
# 	Output_words ['boy', 'he', 'hated', 'more']
# Created sample:
# 	Scan time: 24
# 	Input words: ['boy', 'he', 'hated', 'more']
# 	Output_words ['than', 'Dudley,', 'but', 'that']
# Created sample:
# 	Scan time: 26
# 	Input words: ['than', 'Dudley,', 'but', 'that']
# 	Output_words ['was', 'before', 'he', 'met']
# Created sample:
# 	Scan time: 28
# 	Input words: ['was', 'before', 'he', 'met']
# 	Output_words ['Draco', 'Malfoy.', 'Still,', 'first-year']
# Created sample:
# 	Scan time: 30
# 	Input words: ['Draco', 'Malfoy.', 'Still,', 'first-year']
# 	Output_words ['Gryffindors', 'only', 'had', 'Potions']
# Created sample:
# 	Scan time: 32
# 	Input words: ['Gryffindors', 'only', 'had', 'Potions']
# 	Output_words ['with', 'the', 'Slytherins,', 'so']
# Created sample:
# 	Scan time: 34
# 	Input words: ['with', 'the', 'Slytherins,', 'so']
# 	Output_words ['they', "didn't", 'have', 'to']
# Created sample:
# 	Scan time: 36
# 	Input words: ['they', "didn't", 'have', 'to']
# 	Output_words ['put', 'up', 'with', 'Malfoy']
# Created sample:
# 	Scan time: 38
# 	Input words: ['put', 'up', 'with', 'Malfoy']
# 	Output_words ['much.', 'Or', 'at', 'least,']
# Created sample:
# 	Scan time: 40
# 	Input words: ['much.', 'Or', 'at', 'least,']
# 	Output_words ['they', "didn't", 'until', 'they']
# Created sample:
# 	Scan time: 42
# 	Input words: ['they', "didn't", 'until', 'they']
# 	Output_words ['spotted', 'a', 'notice', 'pinned']
# Created sample:
# 	Scan time: 44
# 	Input words: ['spotted', 'a', 'notice', 'pinned']
# 	Output_words ['up', 'in', 'the', 'Gryffindor']
# Created sample:
# 	Scan time: 46
# 	Input words: ['up', 'in', 'the', 'Gryffindor']
# 	Output_words ['common', 'room', 'that', 'made']
# Created sample:
# 	Scan time: 48
# 	Input words: ['common', 'room', 'that', 'made']
# 	Output_words ['them', 'all', 'groan.', 'Flying']
# Created sample:
# 	Scan time: 50
# 	Input words: ['them', 'all', 'groan.', 'Flying']
# 	Output_words ['lessons', 'would', 'be', 'starting']
# Created sample:
# 	Scan time: 52
# 	Input words: ['lessons', 'would', 'be', 'starting']
# 	Output_words ['on', 'Thursday', '--', 'and']
# Created sample:
# 	Scan time: 54
# 	Input words: ['on', 'Thursday', '--', 'and']
# 	Output_words ['Gryffindor', 'and', 'Slytherin', 'would']
# Created sample:
# 	Scan time: 56
# 	Input words: ['Gryffindor', 'and', 'Slytherin', 'would']
# 	Output_words ['be', 'learning', 'together.', '+']
# Created sample:
# 	Scan time: 58
# 	Input words: ['be', 'learning', 'together.', '+']
# 	Output_words ['"Typical,"', 'said', 'Harry', 'darkly.']
# Created sample:
# 	Scan time: 60
# 	Input words: ['"Typical,"', 'said', 'Harry', 'darkly.']
# 	Output_words ['"Just', 'what', 'I', 'always']
# Created sample:
# 	Scan time: 62
# 	Input words: ['"Just', 'what', 'I', 'always']
# 	Output_words ['wanted.', 'To', 'make', 'a']
# Created sample:
# 	Scan time: 64
# 	Input words: ['wanted.', 'To', 'make', 'a']
# 	Output_words ['fool', 'of', 'myself', 'on']
# Created sample:
# 	Scan time: 66
# 	Input words: ['fool', 'of', 'myself', 'on']
# 	Output_words ['a', 'broomstick', 'in', 'front']
# Created sample:
# 	Scan time: 68
# 	Input words: ['a', 'broomstick', 'in', 'front']
# 	Output_words ['of', 'Malfoy."', '+', 'He']
# Created sample:
# 	Scan time: 70
# 	Input words: ['of', 'Malfoy."', '+', 'He']
# 	Output_words ['had', 'been', 'looking', 'forward']
# Created sample:
# 	Scan time: 72
# 	Input words: ['had', 'been', 'looking', 'forward']
# 	Output_words ['to', 'learning', 'to', 'fly']
# Created sample:
# 	Scan time: 74
# 	Input words: ['to', 'learning', 'to', 'fly']
# 	Output_words ['more', 'than', 'anything', 'else.']
# Created sample:
# 	Scan time: 76
# 	Input words: ['more', 'than', 'anything', 'else.']
# 	Output_words ['"You', "don't", 'know', 'that']
# Created sample:
# 	Scan time: 78
# 	Input words: ['"You', "don't", 'know', 'that']
# 	Output_words ["you'll", 'make', 'a', 'fool']
# Created sample:
# 	Scan time: 80
# 	Input words: ["you'll", 'make', 'a', 'fool']
# 	Output_words ['of', 'yourself,"', 'said', 'Ron']
# Created sample:
# 	Scan time: 82
# 	Input words: ['of', 'yourself,"', 'said', 'Ron']
# 	Output_words ['reasonably.', '"Anyway,', 'I', 'know']
# Created sample:
# 	Scan time: 84
# 	Input words: ['reasonably.', '"Anyway,', 'I', 'know']
# 	Output_words ["Malfoy's", 'always', 'going', 'on']
# Created sample:
# 	Scan time: 86
# 	Input words: ["Malfoy's", 'always', 'going', 'on']
# 	Output_words ['about', 'how', 'good', 'he']
# Created sample:
# 	Scan time: 88
# 	Input words: ['about', 'how', 'good', 'he']
# 	Output_words ['is', 'at', 'Quidditch,', 'but']
# Created sample:
# 	Scan time: 90
# 	Input words: ['is', 'at', 'Quidditch,', 'but']
# 	Output_words ['I', 'bet', "that's", 'all']
# Created sample:
# 	Scan time: 92
# 	Input words: ['I', 'bet', "that's", 'all']
# 	Output_words ['talk."', '+', 'Malfoy', 'certainly']
# Created sample:
# 	Scan time: 94
# 	Input words: ['talk."', '+', 'Malfoy', 'certainly']
# 	Output_words ['did', 'talk', 'about', 'flying']
# Created sample:
# 	Scan time: 96
# 	Input words: ['did', 'talk', 'about', 'flying']
# 	Output_words ['a', 'lot.', 'He', 'complained']
# Created sample:
# 	Scan time: 98
# 	Input words: ['a', 'lot.', 'He', 'complained']
# 	Output_words ['loudly', 'about', 'first', 'years']
# Created sample:
# 	Scan time: 100
# 	Input words: ['loudly', 'about', 'first', 'years']
# 	Output_words ['never', 'getting', 'on', 'the']
# Created sample:
# 	Scan time: 102
# 	Input words: ['never', 'getting', 'on', 'the']
# 	Output_words ['House', 'Quidditch', 'teams', 'and']
# Created sample:
# 	Scan time: 104
# 	Input words: ['House', 'Quidditch', 'teams', 'and']
# 	Output_words ['told', 'long,', 'boastful', 'stories']
# Created sample:
# 	Scan time: 106
# 	Input words: ['told', 'long,', 'boastful', 'stories']
# 	Output_words ['that', 'always', 'seemed', 'to']
# Created sample:
# 	Scan time: 108
# 	Input words: ['that', 'always', 'seemed', 'to']
# 	Output_words ['end', 'with', 'him', 'narrowly']
# Created sample:
# 	Scan time: 110
# 	Input words: ['end', 'with', 'him', 'narrowly']
# 	Output_words ['escaping', 'Muggles', 'in', 'helicopters.']
# Created sample:
# 	Scan time: 112
# 	Input words: ['escaping', 'Muggles', 'in', 'helicopters.']
# 	Output_words ['He', "wasn't", 'the', 'only']
# Created sample:
# 	Scan time: 114
# 	Input words: ['He', "wasn't", 'the', 'only']
# 	Output_words ['one,', 'though:', 'the', 'way']
# Created sample:
# 	Scan time: 116
# 	Input words: ['one,', 'though:', 'the', 'way']
# 	Output_words ['Seamus', 'Finnigan', 'told', 'it,']
# Created sample:
# 	Scan time: 118
# 	Input words: ['Seamus', 'Finnigan', 'told', 'it,']
# 	Output_words ["he'd", 'spent', 'most', 'of']
# Created sample:
# 	Scan time: 120
# 	Input words: ["he'd", 'spent', 'most', 'of']
# 	Output_words ['his', 'childhood', 'zooming', 'around']
# Created sample:
# 	Scan time: 122
# 	Input words: ['his', 'childhood', 'zooming', 'around']
# 	Output_words ['the', 'countryside', 'on', 'his']
# Created sample:
# 	Scan time: 124
# 	Input words: ['the', 'countryside', 'on', 'his']
# 	Output_words ['broomstick.', 'Even', 'Ron', 'would']
# Created sample:
# 	Scan time: 126
# 	Input words: ['broomstick.', 'Even', 'Ron', 'would']
# 	Output_words ['tell', 'anyone', "who'd", 'listen']
# Created sample:
# 	Scan time: 128
# 	Input words: ['tell', 'anyone', "who'd", 'listen']
# 	Output_words ['about', 'the', 'time', "he'd"]
# Created sample:
# 	Scan time: 130
# 	Input words: ['about', 'the', 'time', "he'd"]
# 	Output_words ['almost', 'hit', 'a', 'hang']
# Created sample:
# 	Scan time: 132
# 	Input words: ['almost', 'hit', 'a', 'hang']
# 	Output_words ['glider', 'on', "Charlie's", 'old']
# Created sample:
# 	Scan time: 134
# 	Input words: ['glider', 'on', "Charlie's", 'old']
# 	Output_words ['broom.', 'Everyone', 'from', 'wizarding']
# Created sample:
# 	Scan time: 136
# 	Input words: ['broom.', 'Everyone', 'from', 'wizarding']
# 	Output_words ['families', 'talked', 'about', 'Quidditch']
# Created sample:
# 	Scan time: 138
# 	Input words: ['families', 'talked', 'about', 'Quidditch']
# 	Output_words ['constantly.', 'Ron', 'had', 'already']
# Created sample:
# 	Scan time: 140
# 	Input words: ['constantly.', 'Ron', 'had', 'already']
# 	Output_words ['had', 'a', 'big', 'argument']
# Created sample:
# 	Scan time: 142
# 	Input words: ['had', 'a', 'big', 'argument']
# 	Output_words ['with', 'Dean', 'Thomas,', 'who']
# Created sample:
# 	Scan time: 144
# 	Input words: ['with', 'Dean', 'Thomas,', 'who']
# 	Output_words ['shared', 'their', 'dormitory,', 'about']
# Created sample:
# 	Scan time: 146
# 	Input words: ['shared', 'their', 'dormitory,', 'about']
# 	Output_words ['soccer.', 'Ron', "couldn't", 'see']
# Created sample:
# 	Scan time: 148
# 	Input words: ['soccer.', 'Ron', "couldn't", 'see']
# 	Output_words ['what', 'was', 'exciting', 'about']
# Created sample:
# 	Scan time: 150
# 	Input words: ['what', 'was', 'exciting', 'about']
# 	Output_words ['a', 'game', 'with', 'only']
# Created sample:
# 	Scan time: 152
# 	Input words: ['a', 'game', 'with', 'only']
# 	Output_words ['one', 'ball', 'where', 'no']
# Created sample:
# 	Scan time: 154
# 	Input words: ['one', 'ball', 'where', 'no']
# 	Output_words ['one', 'was', 'allowed', 'to']
# Created sample:
# 	Scan time: 156
# 	Input words: ['one', 'was', 'allowed', 'to']
# 	Output_words ['fly.', 'Harry', 'had', 'caught']
# Created sample:
# 	Scan time: 158
# 	Input words: ['fly.', 'Harry', 'had', 'caught']
# 	Output_words ['Ron', 'prodding', "Dean's", 'poster']
# Created sample:
# 	Scan time: 160
# 	Input words: ['Ron', 'prodding', "Dean's", 'poster']
# 	Output_words ['of', 'West', 'Ham', 'soccer']
# Created sample:
# 	Scan time: 162
# 	Input words: ['of', 'West', 'Ham', 'soccer']
# 	Output_words ['team,', 'trying', 'to', 'make']
# Created sample:
# 	Scan time: 164
# 	Input words: ['team,', 'trying', 'to', 'make']
# 	Output_words ['the', 'players', 'move.', '+']
# Created sample:
# 	Scan time: 166
# 	Input words: ['the', 'players', 'move.', '+']
# 	Output_words ['Neville', 'had', 'never', 'been']
# Created sample:
# 	Scan time: 168
# 	Input words: ['Neville', 'had', 'never', 'been']
# 	Output_words ['on', 'a', 'broomstick', 'in']
# Created sample:
# 	Scan time: 170
# 	Input words: ['on', 'a', 'broomstick', 'in']
# 	Output_words ['his', 'life,', 'because', 'his']
# Created sample:
# 	Scan time: 172
# 	Input words: ['his', 'life,', 'because', 'his']
# 	Output_words ['grandmother', 'had', 'never', 'let']
# Created sample:
# 	Scan time: 174
# 	Input words: ['grandmother', 'had', 'never', 'let']
# 	Output_words ['him', 'near', 'one.', 'Privately,']
# Created sample:
# 	Scan time: 176
# 	Input words: ['him', 'near', 'one.', 'Privately,']
# 	Output_words ['Harry', 'felt', "she'd", 'had']
# Created sample:
# 	Scan time: 178
# 	Input words: ['Harry', 'felt', "she'd", 'had']
# 	Output_words ['good', 'reason,', 'because', 'Neville']
# Created sample:
# 	Scan time: 180
# 	Input words: ['good', 'reason,', 'because', 'Neville']
# 	Output_words ['managed', 'to', 'have', 'an']
# Created sample:
# 	Scan time: 182
# 	Input words: ['managed', 'to', 'have', 'an']
# 	Output_words ['extraordinary', 'number', 'of', 'accidents']
# Created sample:
# 	Scan time: 184
# 	Input words: ['extraordinary', 'number', 'of', 'accidents']
# 	Output_words ['even', 'with', 'both', 'feet']
# Created sample:
# 	Scan time: 186
# 	Input words: ['even', 'with', 'both', 'feet']
# 	Output_words ['on', 'the', 'ground.', '+']
# Created sample:
# 	Scan time: 188
# 	Input words: ['on', 'the', 'ground.', '+']
# 	Output_words ['Hermione', 'Granger', 'was', 'almost']
# Created sample:
# 	Scan time: 190
# 	Input words: ['Hermione', 'Granger', 'was', 'almost']
# 	Output_words ['as', 'nervous', 'about', 'flying']
# Created sample:
# 	Scan time: 192
# 	Input words: ['as', 'nervous', 'about', 'flying']
# 	Output_words ['as', 'Neville', 'was.', 'This']
# Created sample:
# 	Scan time: 194
# 	Input words: ['as', 'Neville', 'was.', 'This']
# 	Output_words ['was', 'something', 'you', "couldn't"]
# Created sample:
# 	Scan time: 196
# 	Input words: ['was', 'something', 'you', "couldn't"]
# 	Output_words ['learn', 'by', 'heart', 'out']
# Created sample:
# 	Scan time: 198
# 	Input words: ['learn', 'by', 'heart', 'out']
# 	Output_words ['of', 'a', 'book', '--']
# Created sample:
# 	Scan time: 200
# 	Input words: ['of', 'a', 'book', '--']
# 	Output_words ['not', 'that', 'she', "hadn't"]
# Created sample:
# 	Scan time: 202
# 	Input words: ['not', 'that', 'she', "hadn't"]
# 	Output_words ['tried.', 'At', 'breakfast', 'on']
# Created sample:
# 	Scan time: 204
# 	Input words: ['tried.', 'At', 'breakfast', 'on']
# 	Output_words ['Thursday', 'she', 'bored', 'them']
# Created sample:
# 	Scan time: 206
# 	Input words: ['Thursday', 'she', 'bored', 'them']
# 	Output_words ['all', 'stupid', 'with', 'flying']
# Created sample:
# 	Scan time: 208
# 	Input words: ['all', 'stupid', 'with', 'flying']
# 	Output_words ['tips', "she'd", 'gotten', 'out']
# Created sample:
# 	Scan time: 210
# 	Input words: ['tips', "she'd", 'gotten', 'out']
# 	Output_words ['of', 'a', 'library', 'book']
# Created sample:
# 	Scan time: 212
# 	Input words: ['of', 'a', 'library', 'book']
# 	Output_words ['called', '@Quidditch', '@Through', '@the']
# Created sample:
# 	Scan time: 214
# 	Input words: ['called', '@Quidditch', '@Through', '@the']
# 	Output_words ['@Ages.', 'Neville', 'was', 'hanging']
# Created sample:
# 	Scan time: 216
# 	Input words: ['@Ages.', 'Neville', 'was', 'hanging']
# 	Output_words ['on', 'to', 'her', 'every']
# Created sample:
# 	Scan time: 218
# 	Input words: ['on', 'to', 'her', 'every']
# 	Output_words ['word,', 'desperate', 'for', 'anything']
# Created sample:
# 	Scan time: 220
# 	Input words: ['word,', 'desperate', 'for', 'anything']
# 	Output_words ['that', 'might', 'help', 'him']
# Created sample:
# 	Scan time: 222
# 	Input words: ['that', 'might', 'help', 'him']
# 	Output_words ['hang', 'on', 'to', 'his']
# Created sample:
# 	Scan time: 224
# 	Input words: ['hang', 'on', 'to', 'his']
# 	Output_words ['broomstick', 'later,', 'but', 'everybody']
# Created sample:
# 	Scan time: 226
# 	Input words: ['broomstick', 'later,', 'but', 'everybody']
# 	Output_words ['else', 'was', 'very', 'pleased']
# Created sample:
# 	Scan time: 228
# 	Input words: ['else', 'was', 'very', 'pleased']
# 	Output_words ['when', "Hermione's", 'lecture', 'was']
# Created sample:
# 	Scan time: 230
# 	Input words: ['when', "Hermione's", 'lecture', 'was']
# 	Output_words ['interrupted', 'by', 'the', 'arrival']
# Created sample:
# 	Scan time: 232
# 	Input words: ['interrupted', 'by', 'the', 'arrival']
# 	Output_words ['of', 'the', 'mail.', '+']
# Created sample:
# 	Scan time: 234
# 	Input words: ['of', 'the', 'mail.', '+']
# 	Output_words ['Harry', "hadn't", 'had', 'a']
# Created sample:
# 	Scan time: 236
# 	Input words: ['Harry', "hadn't", 'had', 'a']
# 	Output_words ['single', 'letter', 'since', "Hagrid's"]
# Created sample:
# 	Scan time: 238
# 	Input words: ['single', 'letter', 'since', "Hagrid's"]
# 	Output_words ['note,', 'something', 'that', 'Malfoy']
# Created sample:
# 	Scan time: 240
# 	Input words: ['note,', 'something', 'that', 'Malfoy']
# 	Output_words ['had', 'been', 'quick', 'to']
# Created sample:
# 	Scan time: 242
# 	Input words: ['had', 'been', 'quick', 'to']
# 	Output_words ['notice,', 'of', 'course.', "Malfoy's"]
# Created sample:
# 	Scan time: 244
# 	Input words: ['notice,', 'of', 'course.', "Malfoy's"]
# 	Output_words ['eagle', 'owl', 'was', 'always']
# Created sample:
# 	Scan time: 246
# 	Input words: ['eagle', 'owl', 'was', 'always']
# 	Output_words ['bringing', 'him', 'packages', 'of']
# Created sample:
# 	Scan time: 248
# 	Input words: ['bringing', 'him', 'packages', 'of']
# 	Output_words ['sweets', 'from', 'home,', 'which']
# Created sample:
# 	Scan time: 250
# 	Input words: ['sweets', 'from', 'home,', 'which']
# 	Output_words ['he', 'opened', 'gloatingly', 'at']
# Created sample:
# 	Scan time: 252
# 	Input words: ['he', 'opened', 'gloatingly', 'at']
# 	Output_words ['the', 'Slytherin', 'table.', '+']
# Created sample:
# 	Scan time: 254
# 	Input words: ['the', 'Slytherin', 'table.', '+']
# 	Output_words ['A', 'barn', 'owl', 'brought']
# Created sample:
# 	Scan time: 256
# 	Input words: ['A', 'barn', 'owl', 'brought']
# 	Output_words ['Neville', 'a', 'small', 'package']
# Created sample:
# 	Scan time: 258
# 	Input words: ['Neville', 'a', 'small', 'package']
# 	Output_words ['from', 'his', 'grandmother.', 'He']
# Created sample:
# 	Scan time: 260
# 	Input words: ['from', 'his', 'grandmother.', 'He']
# 	Output_words ['opened', 'it', 'excitedly', 'and']
# Created sample:
# 	Scan time: 262
# 	Input words: ['opened', 'it', 'excitedly', 'and']
# 	Output_words ['showed', 'them', 'a', 'glass']
# Created sample:
# 	Scan time: 264
# 	Input words: ['showed', 'them', 'a', 'glass']
# 	Output_words ['ball', 'the', 'size', 'of']
# Created sample:
# 	Scan time: 266
# 	Input words: ['ball', 'the', 'size', 'of']
# 	Output_words ['a', 'large', 'marble,', 'which']
# Created sample:
# 	Scan time: 268
# 	Input words: ['a', 'large', 'marble,', 'which']
# 	Output_words ['seemed', 'to', 'be', 'full']
# Created sample:
# 	Scan time: 270
# 	Input words: ['seemed', 'to', 'be', 'full']
# 	Output_words ['of', 'white', 'smoke.', '+']
# Created sample:
# 	Scan time: 272
# 	Input words: ['of', 'white', 'smoke.', '+']
# 	Output_words ['"It\'s', 'a', 'Remembrall!"', 'he']
# Created sample:
# 	Scan time: 274
# 	Input words: ['"It\'s', 'a', 'Remembrall!"', 'he']
# 	Output_words ['explained.', '"Gran', 'knows', 'I']
# Created sample:
# 	Scan time: 276
# 	Input words: ['explained.', '"Gran', 'knows', 'I']
# 	Output_words ['forget', 'things', '--', 'this']
# Created sample:
# 	Scan time: 278
# 	Input words: ['forget', 'things', '--', 'this']
# 	Output_words ['tells', 'you', 'if', "there's"]
# Created sample:
# 	Scan time: 280
# 	Input words: ['tells', 'you', 'if', "there's"]
# 	Output_words ['something', "you've", 'forgotten', 'to']
# Created sample:
# 	Scan time: 282
# 	Input words: ['something', "you've", 'forgotten', 'to']
# 	Output_words ['do.', 'Look,', 'you', 'hold']
# Created sample:
# 	Scan time: 284
# 	Input words: ['do.', 'Look,', 'you', 'hold']
# 	Output_words ['it', 'tight', 'like', 'this']
# Created sample:
# 	Scan time: 286
# 	Input words: ['it', 'tight', 'like', 'this']
# 	Output_words ['and', 'if', 'it', 'turns']
# Created sample:
# 	Scan time: 288
# 	Input words: ['and', 'if', 'it', 'turns']
# 	Output_words ['red', '--', 'oh', '…"']
# Created sample:
# 	Scan time: 290
# 	Input words: ['red', '--', 'oh', '…"']
# 	Output_words ['His', 'face', 'fell,', 'because']
# Created sample:
# 	Scan time: 292
# 	Input words: ['His', 'face', 'fell,', 'because']
# 	Output_words ['the', 'Remembrall', 'had', 'suddenly']
# Created sample:
# 	Scan time: 294
# 	Input words: ['the', 'Remembrall', 'had', 'suddenly']
# 	Output_words ['glowed', 'scarlet,', '"…', "you've"]
# Created sample:
# 	Scan time: 296
# 	Input words: ['glowed', 'scarlet,', '"…', "you've"]
# 	Output_words ['forgotten', 'something', '…"', '+']
# Created sample:
# 	Scan time: 298
# 	Input words: ['forgotten', 'something', '…"', '+']
# 	Output_words ['Neville', 'was', 'trying', 'to']
# Created sample:
# 	Scan time: 300
# 	Input words: ['Neville', 'was', 'trying', 'to']
# 	Output_words ['remember', 'what', "he'd", 'forgotten']
# Created sample:
# 	Scan time: 302
# 	Input words: ['remember', 'what', "he'd", 'forgotten']
# 	Output_words ['when', 'Draco', 'Malfoy,', 'who']
# Created sample:
# 	Scan time: 304
# 	Input words: ['when', 'Draco', 'Malfoy,', 'who']
# 	Output_words ['was', 'passing', 'the', 'Gryffindor']
# Created sample:
# 	Scan time: 306
# 	Input words: ['was', 'passing', 'the', 'Gryffindor']
# 	Output_words ['table,', 'snatched', 'the', 'Remembrall']
# Created sample:
# 	Scan time: 308
# 	Input words: ['table,', 'snatched', 'the', 'Remembrall']
# 	Output_words ['out', 'of', 'his', 'hand.']
# Created sample:
# 	Scan time: 310
# 	Input words: ['out', 'of', 'his', 'hand.']
# 	Output_words ['+', 'Harry', 'and', 'Ron']
# Created sample:
# 	Scan time: 312
# 	Input words: ['+', 'Harry', 'and', 'Ron']
# 	Output_words ['jumped', 'to', 'their', 'feet.']
# Created sample:
# 	Scan time: 314
# 	Input words: ['jumped', 'to', 'their', 'feet.']
# 	Output_words ['They', 'were', 'half', 'hoping']
# Created sample:
# 	Scan time: 316
# 	Input words: ['They', 'were', 'half', 'hoping']
# 	Output_words ['for', 'a', 'reason', 'to']
# Created sample:
# 	Scan time: 318
# 	Input words: ['for', 'a', 'reason', 'to']
# 	Output_words ['fight', 'Malfoy,', 'but', 'Professor']
# Created sample:
# 	Scan time: 320
# 	Input words: ['fight', 'Malfoy,', 'but', 'Professor']
# 	Output_words ['McGonagall,', 'who', 'could', 'spot']
# Created sample:
# 	Scan time: 322
# 	Input words: ['McGonagall,', 'who', 'could', 'spot']
# 	Output_words ['trouble', 'quicker', 'than', 'any']
# Created sample:
# 	Scan time: 324
# 	Input words: ['trouble', 'quicker', 'than', 'any']
# 	Output_words ['teacher', 'in', 'the', 'school,']
# Created sample:
# 	Scan time: 326
# 	Input words: ['teacher', 'in', 'the', 'school,']
# 	Output_words ['was', 'there', 'in', 'a']
# Created sample:
# 	Scan time: 328
# 	Input words: ['was', 'there', 'in', 'a']
# 	Output_words ['flash.', '+', '"What\'s', 'going']
# Created sample:
# 	Scan time: 330
# 	Input words: ['flash.', '+', '"What\'s', 'going']
# 	Output_words ['on?"', '+', '"Malfoy\'s', 'got']
# Created sample:
# 	Scan time: 332
# 	Input words: ['on?"', '+', '"Malfoy\'s', 'got']
# 	Output_words ['my', 'Remembrall,', 'Professor."', '+']
# Created sample:
# 	Scan time: 334
# 	Input words: ['my', 'Remembrall,', 'Professor."', '+']
# 	Output_words ['Scowling,', 'Malfoy', 'quickly', 'dropped']
# Created sample:
# 	Scan time: 336
# 	Input words: ['Scowling,', 'Malfoy', 'quickly', 'dropped']
# 	Output_words ['the', 'Remembrall', 'back', 'on']
# Created sample:
# 	Scan time: 338
# 	Input words: ['the', 'Remembrall', 'back', 'on']
# 	Output_words ['the', 'table.', '+', '"Just']
# Created sample:
# 	Scan time: 340
# 	Input words: ['the', 'table.', '+', '"Just']
# 	Output_words ['looking,"', 'he', 'said,', 'and']
# Created sample:
# 	Scan time: 342
# 	Input words: ['looking,"', 'he', 'said,', 'and']
# 	Output_words ['he', 'sloped', 'away', 'with']
# Created sample:
# 	Scan time: 344
# 	Input words: ['he', 'sloped', 'away', 'with']
# 	Output_words ['Crabbe', 'and', 'Goyle', 'behind']
# Created sample:
# 	Scan time: 346
# 	Input words: ['Crabbe', 'and', 'Goyle', 'behind']
# 	Output_words ['him.', '+', '+', 'At']
# Created sample:
# 	Scan time: 348
# 	Input words: ['him.', '+', '+', 'At']
# 	Output_words ['three-thirty', 'that', 'afternoon,', 'Harry,']
# Created sample:
# 	Scan time: 350
# 	Input words: ['three-thirty', 'that', 'afternoon,', 'Harry,']
# 	Output_words ['Ron,', 'and', 'the', 'other']
# Created sample:
# 	Scan time: 352
# 	Input words: ['Ron,', 'and', 'the', 'other']
# 	Output_words ['Gryffindors', 'hurried', 'down', 'the']
# Created sample:
# 	Scan time: 354
# 	Input words: ['Gryffindors', 'hurried', 'down', 'the']
# 	Output_words ['front', 'steps', 'onto', 'the']
# Created sample:
# 	Scan time: 356
# 	Input words: ['front', 'steps', 'onto', 'the']
# 	Output_words ['grounds', 'for', 'their', 'first']
# Created sample:
# 	Scan time: 358
# 	Input words: ['grounds', 'for', 'their', 'first']
# 	Output_words ['flying', 'lesson.', 'It', 'was']
# Created sample:
# 	Scan time: 360
# 	Input words: ['flying', 'lesson.', 'It', 'was']
# 	Output_words ['a', 'clear,', 'breezy', 'day,']
# Created sample:
# 	Scan time: 362
# 	Input words: ['a', 'clear,', 'breezy', 'day,']
# 	Output_words ['and', 'the', 'grass', 'rippled']
# Created sample:
# 	Scan time: 364
# 	Input words: ['and', 'the', 'grass', 'rippled']
# 	Output_words ['under', 'their', 'feet', 'as']
# Created sample:
# 	Scan time: 366
# 	Input words: ['under', 'their', 'feet', 'as']
# 	Output_words ['they', 'marched', 'down', 'the']
# Created sample:
# 	Scan time: 368
# 	Input words: ['they', 'marched', 'down', 'the']
# 	Output_words ['sloping', 'lawns', 'toward', 'a']
# Created sample:
# 	Scan time: 370
# 	Input words: ['sloping', 'lawns', 'toward', 'a']
# 	Output_words ['smooth,', 'flat', 'lawn', 'on']
# Created sample:
# 	Scan time: 372
# 	Input words: ['smooth,', 'flat', 'lawn', 'on']
# 	Output_words ['the', 'opposite', 'side', 'of']
# Created sample:
# 	Scan time: 374
# 	Input words: ['the', 'opposite', 'side', 'of']
# 	Output_words ['the', 'grounds', 'to', 'the']
# Created sample:
# 	Scan time: 376
# 	Input words: ['the', 'grounds', 'to', 'the']
# 	Output_words ['forbidden', 'forest,', 'whose', 'trees']
# Created sample:
# 	Scan time: 378
# 	Input words: ['forbidden', 'forest,', 'whose', 'trees']
# 	Output_words ['were', 'swaying', 'darkly', 'in']
# Created sample:
# 	Scan time: 380
# 	Input words: ['were', 'swaying', 'darkly', 'in']
# 	Output_words ['the', 'distance.', '+', 'The']
# Created sample:
# 	Scan time: 382
# 	Input words: ['the', 'distance.', '+', 'The']
# 	Output_words ['Slytherins', 'were', 'already', 'there,']
# Created sample:
# 	Scan time: 384
# 	Input words: ['Slytherins', 'were', 'already', 'there,']
# 	Output_words ['and', 'so', 'were', 'twenty']
# Created sample:
# 	Scan time: 386
# 	Input words: ['and', 'so', 'were', 'twenty']
# 	Output_words ['broomsticks', 'lying', 'in', 'neat']
# Created sample:
# 	Scan time: 388
# 	Input words: ['broomsticks', 'lying', 'in', 'neat']
# 	Output_words ['lines', 'on', 'the', 'ground.']
# Created sample:
# 	Scan time: 390
# 	Input words: ['lines', 'on', 'the', 'ground.']
# 	Output_words ['Harry', 'had', 'heard', 'Fred']
# Created sample:
# 	Scan time: 392
# 	Input words: ['Harry', 'had', 'heard', 'Fred']
# 	Output_words ['and', 'George', 'Weasley', 'complain']
# Created sample:
# 	Scan time: 394
# 	Input words: ['and', 'George', 'Weasley', 'complain']
# 	Output_words ['about', 'the', 'school', 'brooms,']
# Created sample:
# 	Scan time: 396
# 	Input words: ['about', 'the', 'school', 'brooms,']
# 	Output_words ['saying', 'that', 'some', 'of']
# Created sample:
# 	Scan time: 398
# 	Input words: ['saying', 'that', 'some', 'of']
# 	Output_words ['them', 'started', 'to', 'vibrate']
# Created sample:
# 	Scan time: 400
# 	Input words: ['them', 'started', 'to', 'vibrate']
# 	Output_words ['if', 'you', 'flew', 'too']
# Created sample:
# 	Scan time: 402
# 	Input words: ['if', 'you', 'flew', 'too']
# 	Output_words ['high,', 'or', 'always', 'flew']
# Created sample:
# 	Scan time: 404
# 	Input words: ['high,', 'or', 'always', 'flew']
# 	Output_words ['slightly', 'to', 'the', 'left.']
# Created sample:
# 	Scan time: 406
# 	Input words: ['slightly', 'to', 'the', 'left.']
# 	Output_words ['+', 'Their', 'teacher,', 'Madam']
# Created sample:
# 	Scan time: 408
# 	Input words: ['+', 'Their', 'teacher,', 'Madam']
# 	Output_words ['Hooch,', 'arrived.', 'She', 'had']
# Created sample:
# 	Scan time: 410
# 	Input words: ['Hooch,', 'arrived.', 'She', 'had']
# 	Output_words ['short,', 'gray', 'hair,', 'and']
# Created sample:
# 	Scan time: 412
# 	Input words: ['short,', 'gray', 'hair,', 'and']
# 	Output_words ['yellow', 'eyes', 'like', 'a']
# Created sample:
# 	Scan time: 414
# 	Input words: ['yellow', 'eyes', 'like', 'a']
# 	Output_words ['hawk.', '+', '"Well,', 'what']
# Created sample:
# 	Scan time: 416
# 	Input words: ['hawk.', '+', '"Well,', 'what']
# 	Output_words ['are', 'you', 'all', 'waiting']
# Created sample:
# 	Scan time: 418
# 	Input words: ['are', 'you', 'all', 'waiting']
# 	Output_words ['for?"', 'she', 'barked.', '"Everyone']
# Created sample:
# 	Scan time: 420
# 	Input words: ['for?"', 'she', 'barked.', '"Everyone']
# 	Output_words ['stand', 'by', 'a', 'broomstick.']
# Created sample:
# 	Scan time: 422
# 	Input words: ['stand', 'by', 'a', 'broomstick.']
# 	Output_words ['Come', 'on,', 'hurry', 'up."']
# Created sample:
# 	Scan time: 424
# 	Input words: ['Come', 'on,', 'hurry', 'up."']
# 	Output_words ['+', 'Harry', 'glanced', 'down']
# Created sample:
# 	Scan time: 426
# 	Input words: ['+', 'Harry', 'glanced', 'down']
# 	Output_words ['at', 'his', 'broom.', 'It']
# Created sample:
# 	Scan time: 428
# 	Input words: ['at', 'his', 'broom.', 'It']
# 	Output_words ['was', 'old', 'and', 'some']
# Created sample:
# 	Scan time: 430
# 	Input words: ['was', 'old', 'and', 'some']
# 	Output_words ['of', 'the', 'twigs', 'stuck']
# Created sample:
# 	Scan time: 432
# 	Input words: ['of', 'the', 'twigs', 'stuck']
# 	Output_words ['out', 'at', 'odd', 'angles.']
# Created sample:
# 	Scan time: 434
# 	Input words: ['out', 'at', 'odd', 'angles.']
# 	Output_words ['+', '"Stick', 'out', 'your']
# Created sample:
# 	Scan time: 436
# 	Input words: ['+', '"Stick', 'out', 'your']
# 	Output_words ['right', 'hand', 'over', 'your']
# Created sample:
# 	Scan time: 438
# 	Input words: ['right', 'hand', 'over', 'your']
# 	Output_words ['broom,"', 'called', 'Madam', 'Hooch']
# Created sample:
# 	Scan time: 440
# 	Input words: ['broom,"', 'called', 'Madam', 'Hooch']
# 	Output_words ['at', 'the', 'front,', '"and']
# Created sample:
# 	Scan time: 442
# 	Input words: ['at', 'the', 'front,', '"and']
# 	Output_words ['say', '‘Up!\'"', '+', '"UP!"']
# Created sample:
# 	Scan time: 444
# 	Input words: ['say', '‘Up!\'"', '+', '"UP!"']
# 	Output_words ['everyone', 'shouted.', '+', "Harry's"]
# Created sample:
# 	Scan time: 446
# 	Input words: ['everyone', 'shouted.', '+', "Harry's"]
# 	Output_words ['broom', 'jumped', 'into', 'his']
# Created sample:
# 	Scan time: 448
# 	Input words: ['broom', 'jumped', 'into', 'his']
# 	Output_words ['hand', 'at', 'once,', 'but']
# Created sample:
# 	Scan time: 450
# 	Input words: ['hand', 'at', 'once,', 'but']
# 	Output_words ['it', 'was', 'one', 'of']
# Created sample:
# 	Scan time: 452
# 	Input words: ['it', 'was', 'one', 'of']
# 	Output_words ['the', 'few', 'that', 'did.']
# Created sample:
# 	Scan time: 454
# 	Input words: ['the', 'few', 'that', 'did.']
# 	Output_words ['Hermione', "Granger's", 'had', 'simply']
# Created sample:
# 	Scan time: 456
# 	Input words: ['Hermione', "Granger's", 'had', 'simply']
# 	Output_words ['rolled', 'over', 'on', 'the']
# Created sample:
# 	Scan time: 458
# 	Input words: ['rolled', 'over', 'on', 'the']
# 	Output_words ['ground,', 'and', "Neville's", "hadn't"]
# Created sample:
# 	Scan time: 460
# 	Input words: ['ground,', 'and', "Neville's", "hadn't"]
# 	Output_words ['moved', 'at', 'all.', 'Perhaps']
# Created sample:
# 	Scan time: 462
# 	Input words: ['moved', 'at', 'all.', 'Perhaps']
# 	Output_words ['brooms,', 'like', 'horses,', 'could']
# Created sample:
# 	Scan time: 464
# 	Input words: ['brooms,', 'like', 'horses,', 'could']
# 	Output_words ['tell', 'when', 'you', 'were']
# Created sample:
# 	Scan time: 466
# 	Input words: ['tell', 'when', 'you', 'were']
# 	Output_words ['afraid,', 'thought', 'Harry;', 'there']
# Created sample:
# 	Scan time: 468
# 	Input words: ['afraid,', 'thought', 'Harry;', 'there']
# 	Output_words ['was', 'a', 'quaver', 'in']
# Created sample:
# 	Scan time: 470
# 	Input words: ['was', 'a', 'quaver', 'in']
# 	Output_words ["Neville's", 'voice', 'that', 'said']
# Created sample:
# 	Scan time: 472
# 	Input words: ["Neville's", 'voice', 'that', 'said']
# 	Output_words ['only', 'too', 'clearly', 'that']
# Created sample:
# 	Scan time: 474
# 	Input words: ['only', 'too', 'clearly', 'that']
# 	Output_words ['he', 'wanted', 'to', 'keep']
# Created sample:
# 	Scan time: 476
# 	Input words: ['he', 'wanted', 'to', 'keep']
# 	Output_words ['his', 'feet', 'on', 'the']
# Created sample:
# 	Scan time: 478
# 	Input words: ['his', 'feet', 'on', 'the']
# 	Output_words ['ground.', '+', 'Madam', 'Hooch']
# Created sample:
# 	Scan time: 480
# 	Input words: ['ground.', '+', 'Madam', 'Hooch']
# 	Output_words ['then', 'showed', 'them', 'how']
# Created sample:
# 	Scan time: 482
# 	Input words: ['then', 'showed', 'them', 'how']
# 	Output_words ['to', 'mount', 'their', 'brooms']
# Created sample:
# 	Scan time: 484
# 	Input words: ['to', 'mount', 'their', 'brooms']
# 	Output_words ['without', 'sliding', 'off', 'the']
# Created sample:
# 	Scan time: 486
# 	Input words: ['without', 'sliding', 'off', 'the']
# 	Output_words ['end,', 'and', 'walked', 'up']
# Created sample:
# 	Scan time: 488
# 	Input words: ['end,', 'and', 'walked', 'up']
# 	Output_words ['and', 'down', 'the', 'rows']
# Created sample:
# 	Scan time: 490
# 	Input words: ['and', 'down', 'the', 'rows']
# 	Output_words ['correcting', 'their', 'grips.', 'Harry']
# Created sample:
# 	Scan time: 492
# 	Input words: ['correcting', 'their', 'grips.', 'Harry']
# 	Output_words ['and', 'Ron', 'were', 'delighted']
# Created sample:
# 	Scan time: 494
# 	Input words: ['and', 'Ron', 'were', 'delighted']
# 	Output_words ['when', 'she', 'told', 'Malfoy']
# Created sample:
# 	Scan time: 496
# 	Input words: ['when', 'she', 'told', 'Malfoy']
# 	Output_words ["he'd", 'been', 'doing', 'it']
# Created sample:
# 	Scan time: 498
# 	Input words: ["he'd", 'been', 'doing', 'it']
# 	Output_words ['wrong', 'for', 'years.', '+']
# Created sample:
# 	Scan time: 500
# 	Input words: ['wrong', 'for', 'years.', '+']
# 	Output_words ['"Now,', 'when', 'I', 'blow']
# Created sample:
# 	Scan time: 502
# 	Input words: ['"Now,', 'when', 'I', 'blow']
# 	Output_words ['my', 'whistle,', 'you', 'kick']
# Created sample:
# 	Scan time: 504
# 	Input words: ['my', 'whistle,', 'you', 'kick']
# 	Output_words ['off', 'from', 'the', 'ground,']
# Created sample:
# 	Scan time: 506
# 	Input words: ['off', 'from', 'the', 'ground,']
# 	Output_words ['hard,"', 'said', 'Madam', 'Hooch.']
# Created sample:
# 	Scan time: 508
# 	Input words: ['hard,"', 'said', 'Madam', 'Hooch.']
# 	Output_words ['"Keep', 'your', 'brooms', 'steady,']
# Created sample:
# 	Scan time: 510
# 	Input words: ['"Keep', 'your', 'brooms', 'steady,']
# 	Output_words ['rise', 'a', 'few', 'feet,']
# Created sample:
# 	Scan time: 512
# 	Input words: ['rise', 'a', 'few', 'feet,']
# 	Output_words ['and', 'then', 'come', 'straight']
# Created sample:
# 	Scan time: 514
# 	Input words: ['and', 'then', 'come', 'straight']
# 	Output_words ['back', 'down', 'by', 'leaning']
# Created sample:
# 	Scan time: 516
# 	Input words: ['back', 'down', 'by', 'leaning']
# 	Output_words ['forward', 'slightly.', 'On', 'my']
# Created sample:
# 	Scan time: 518
# 	Input words: ['forward', 'slightly.', 'On', 'my']
# 	Output_words ['whistle', '--', 'three', '--']
# Created sample:
# 	Scan time: 520
# 	Input words: ['whistle', '--', 'three', '--']
# 	Output_words ['two', '—"', '+', 'But']
# Created sample:
# 	Scan time: 522
# 	Input words: ['two', '—"', '+', 'But']
# 	Output_words ['Neville,', 'nervous', 'and', 'jumpy']
# Created sample:
# 	Scan time: 524
# 	Input words: ['Neville,', 'nervous', 'and', 'jumpy']
# 	Output_words ['and', 'frightened', 'of', 'being']
# Created sample:
# 	Scan time: 526
# 	Input words: ['and', 'frightened', 'of', 'being']
# 	Output_words ['left', 'on', 'the', 'ground,']
# Created sample:
# 	Scan time: 528
# 	Input words: ['left', 'on', 'the', 'ground,']
# 	Output_words ['pushed', 'off', 'hard', 'before']
# Created sample:
# 	Scan time: 530
# 	Input words: ['pushed', 'off', 'hard', 'before']
# 	Output_words ['the', 'whistle', 'had', 'touched']
# Created sample:
# 	Scan time: 532
# 	Input words: ['the', 'whistle', 'had', 'touched']
# 	Output_words ['Madam', "Hooch's", 'lips.', '+']
# Created sample:
# 	Scan time: 534
# 	Input words: ['Madam', "Hooch's", 'lips.', '+']
# 	Output_words ['"Come', 'back,', 'boy!"', 'she']
# Created sample:
# 	Scan time: 536
# 	Input words: ['"Come', 'back,', 'boy!"', 'she']
# 	Output_words ['shouted,', 'but', 'Neville', 'was']
# Created sample:
# 	Scan time: 538
# 	Input words: ['shouted,', 'but', 'Neville', 'was']
# 	Output_words ['rising', 'straight', 'up', 'like']
# Created sample:
# 	Scan time: 540
# 	Input words: ['rising', 'straight', 'up', 'like']
# 	Output_words ['a', 'cork', 'shot', 'out']
# Created sample:
# 	Scan time: 542
# 	Input words: ['a', 'cork', 'shot', 'out']
# 	Output_words ['of', 'a', 'bottle', '--']
# Created sample:
# 	Scan time: 544
# 	Input words: ['of', 'a', 'bottle', '--']
# 	Output_words ['twelve', 'feet', '--', 'twenty']
# Created sample:
# 	Scan time: 546
# 	Input words: ['twelve', 'feet', '--', 'twenty']
# 	Output_words ['feet.', 'Harry', 'saw', 'his']
# Created sample:
# 	Scan time: 548
# 	Input words: ['feet.', 'Harry', 'saw', 'his']
# 	Output_words ['scared', 'white', 'face', 'look']
# Created sample:
# 	Scan time: 550
# 	Input words: ['scared', 'white', 'face', 'look']
# 	Output_words ['down', 'at', 'the', 'ground']
# Created sample:
# 	Scan time: 552
# 	Input words: ['down', 'at', 'the', 'ground']
# 	Output_words ['falling', 'away,', 'saw', 'him']
# Created sample:
# 	Scan time: 554
# 	Input words: ['falling', 'away,', 'saw', 'him']
# 	Output_words ['gasp,', 'slip', 'sideways', 'off']
# Created sample:
# 	Scan time: 556
# 	Input words: ['gasp,', 'slip', 'sideways', 'off']
# 	Output_words ['the', 'broom', 'and', '--']
# Created sample:
# 	Scan time: 558
# 	Input words: ['the', 'broom', 'and', '--']
# 	Output_words ['+', 'WHAM', '--', 'a']
# Created sample:
# 	Scan time: 560
# 	Input words: ['+', 'WHAM', '--', 'a']
# 	Output_words ['thud', 'and', 'a', 'nasty']
# Created sample:
# 	Scan time: 562
# 	Input words: ['thud', 'and', 'a', 'nasty']
# 	Output_words ['crack', 'and', 'Neville', 'lay']
# Created sample:
# 	Scan time: 564
# 	Input words: ['crack', 'and', 'Neville', 'lay']
# 	Output_words ['facedown', 'on', 'the', 'grass']
# Created sample:
# 	Scan time: 566
# 	Input words: ['facedown', 'on', 'the', 'grass']
# 	Output_words ['in', 'a', 'heap.', 'His']
# Created sample:
# 	Scan time: 568
# 	Input words: ['in', 'a', 'heap.', 'His']
# 	Output_words ['broomstick', 'was', 'still', 'rising']
# Created sample:
# 	Scan time: 570
# 	Input words: ['broomstick', 'was', 'still', 'rising']
# 	Output_words ['higher', 'and', 'higher,', 'and']
# Created sample:
# 	Scan time: 572
# 	Input words: ['higher', 'and', 'higher,', 'and']
# 	Output_words ['started', 'to', 'drift', 'lazily']
# Created sample:
# 	Scan time: 574
# 	Input words: ['started', 'to', 'drift', 'lazily']
# 	Output_words ['toward', 'the', 'forbidden', 'forest']
# Created sample:
# 	Scan time: 576
# 	Input words: ['toward', 'the', 'forbidden', 'forest']
# 	Output_words ['and', 'out', 'of', 'sight.']
# Created sample:
# 	Scan time: 578
# 	Input words: ['and', 'out', 'of', 'sight.']
# 	Output_words ['+', 'Madam', 'Hooch', 'was']
# Created sample:
# 	Scan time: 580
# 	Input words: ['+', 'Madam', 'Hooch', 'was']
# 	Output_words ['bending', 'over', 'Neville,', 'her']
# Created sample:
# 	Scan time: 582
# 	Input words: ['bending', 'over', 'Neville,', 'her']
# 	Output_words ['face', 'as', 'white', 'as']
# Created sample:
# 	Scan time: 584
# 	Input words: ['face', 'as', 'white', 'as']
# 	Output_words ['his.', '"Broken', 'wrist,"', 'Harry']
# Created sample:
# 	Scan time: 586
# 	Input words: ['his.', '"Broken', 'wrist,"', 'Harry']
# 	Output_words ['heard', 'her', 'mutter.', '"Come']
# Created sample:
# 	Scan time: 588
# 	Input words: ['heard', 'her', 'mutter.', '"Come']
# 	Output_words ['on,', 'boy', '--', "it's"]
# Created sample:
# 	Scan time: 590
# 	Input words: ['on,', 'boy', '--', "it's"]
# 	Output_words ['all', 'right,', 'up', 'you']
# Created sample:
# 	Scan time: 592
# 	Input words: ['all', 'right,', 'up', 'you']
# 	Output_words ['get."', '+', 'She', 'turned']
# Created sample:
# 	Scan time: 594
# 	Input words: ['get."', '+', 'She', 'turned']
# 	Output_words ['to', 'the', 'rest', 'of']
# Created sample:
# 	Scan time: 596
# 	Input words: ['to', 'the', 'rest', 'of']
# 	Output_words ['the', 'class.', '"None', 'of']
# Created sample:
# 	Scan time: 598
# 	Input words: ['the', 'class.', '"None', 'of']
# 	Output_words ['you', 'is', 'to', 'move']
# Created sample:
# 	Scan time: 600
# 	Input words: ['you', 'is', 'to', 'move']
# 	Output_words ['while', 'I', 'take', 'this']
# Created sample:
# 	Scan time: 602
# 	Input words: ['while', 'I', 'take', 'this']
# 	Output_words ['boy', 'to', 'the', 'hospital']
# Created sample:
# 	Scan time: 604
# 	Input words: ['boy', 'to', 'the', 'hospital']
# 	Output_words ['wing!', 'You', 'leave', 'those']
# Created sample:
# 	Scan time: 606
# 	Input words: ['wing!', 'You', 'leave', 'those']
# 	Output_words ['brooms', 'where', 'they', 'are']
# Created sample:
# 	Scan time: 608
# 	Input words: ['brooms', 'where', 'they', 'are']
# 	Output_words ['or', "you'll", 'be', 'out']
# Created sample:
# 	Scan time: 610
# 	Input words: ['or', "you'll", 'be', 'out']
# 	Output_words ['of', 'Hogwarts', 'before', 'you']
# Created sample:
# 	Scan time: 612
# 	Input words: ['of', 'Hogwarts', 'before', 'you']
# 	Output_words ['can', 'say', "‘Quidditch.'", 'Come']
# Created sample:
# 	Scan time: 614
# 	Input words: ['can', 'say', "‘Quidditch.'", 'Come']
# 	Output_words ['on,', 'dear."', '+', 'Neville,']
# Created sample:
# 	Scan time: 616
# 	Input words: ['on,', 'dear."', '+', 'Neville,']
# 	Output_words ['his', 'face', 'tear-streaked,', 'clutching']
# Created sample:
# 	Scan time: 618
# 	Input words: ['his', 'face', 'tear-streaked,', 'clutching']
# 	Output_words ['his', 'wrist,', 'hobbled', 'off']
# Created sample:
# 	Scan time: 620
# 	Input words: ['his', 'wrist,', 'hobbled', 'off']
# 	Output_words ['with', 'Madam', 'Hooch,', 'who']
# Created sample:
# 	Scan time: 622
# 	Input words: ['with', 'Madam', 'Hooch,', 'who']
# 	Output_words ['had', 'her', 'arm', 'around']
# Created sample:
# 	Scan time: 624
# 	Input words: ['had', 'her', 'arm', 'around']
# 	Output_words ['him.', '+', 'No', 'sooner']
# Created sample:
# 	Scan time: 626
# 	Input words: ['him.', '+', 'No', 'sooner']
# 	Output_words ['were', 'they', 'out', 'of']
# Created sample:
# 	Scan time: 628
# 	Input words: ['were', 'they', 'out', 'of']
# 	Output_words ['earshot', 'than', 'Malfoy', 'burst']
# Created sample:
# 	Scan time: 630
# 	Input words: ['earshot', 'than', 'Malfoy', 'burst']
# 	Output_words ['into', 'laughter.', '+', '"Did']
# Created sample:
# 	Scan time: 632
# 	Input words: ['into', 'laughter.', '+', '"Did']
# 	Output_words ['you', 'see', 'his', 'face,']
# Created sample:
# 	Scan time: 634
# 	Input words: ['you', 'see', 'his', 'face,']
# 	Output_words ['the', 'great', 'lump?"', '+']
# Created sample:
# 	Scan time: 636
# 	Input words: ['the', 'great', 'lump?"', '+']
# 	Output_words ['The', 'other', 'Slytherins', 'joined']
# Created sample:
# 	Scan time: 638
# 	Input words: ['The', 'other', 'Slytherins', 'joined']
# 	Output_words ['in.', '+', '"Shut', 'up,']
# Created sample:
# 	Scan time: 640
# 	Input words: ['in.', '+', '"Shut', 'up,']
# 	Output_words ['Malfoy,"', 'snapped', 'Parvati', 'Patil.']
# Created sample:
# 	Scan time: 642
# 	Input words: ['Malfoy,"', 'snapped', 'Parvati', 'Patil.']
# 	Output_words ['+', '"Ooh,', 'sticking', 'up']
# Created sample:
# 	Scan time: 644
# 	Input words: ['+', '"Ooh,', 'sticking', 'up']
# 	Output_words ['for', 'Longbottom?"', 'said', 'Pansy']
# Created sample:
# 	Scan time: 646
# 	Input words: ['for', 'Longbottom?"', 'said', 'Pansy']
# 	Output_words ['Parkinson,', 'a', 'hard-faced', 'Slytherin']
# Created sample:
# 	Scan time: 648
# 	Input words: ['Parkinson,', 'a', 'hard-faced', 'Slytherin']
# 	Output_words ['girl.', '"Never', 'thought', "@you'd"]
# Created sample:
# 	Scan time: 650
# 	Input words: ['girl.', '"Never', 'thought', "@you'd"]
# 	Output_words ['like', 'fat', 'little', 'crybabies,']
# Created sample:
# 	Scan time: 652
# 	Input words: ['like', 'fat', 'little', 'crybabies,']
# 	Output_words ['Parvati."', '+', '"Look!"', 'said']
# Created sample:
# 	Scan time: 654
# 	Input words: ['Parvati."', '+', '"Look!"', 'said']
# 	Output_words ['Malfoy,', 'darting', 'forward', 'and']
# Created sample:
# 	Scan time: 656
# 	Input words: ['Malfoy,', 'darting', 'forward', 'and']
# 	Output_words ['snatching', 'something', 'out', 'of']
# Created sample:
# 	Scan time: 658
# 	Input words: ['snatching', 'something', 'out', 'of']
# 	Output_words ['the', 'grass.', '"It\'s', 'that']
# Created sample:
# 	Scan time: 660
# 	Input words: ['the', 'grass.', '"It\'s', 'that']
# 	Output_words ['stupid', 'thing', "Longbottom's", 'gran']
# Created sample:
# 	Scan time: 662
# 	Input words: ['stupid', 'thing', "Longbottom's", 'gran']
# 	Output_words ['sent', 'him."', '+', 'The']
# Created sample:
# 	Scan time: 664
# 	Input words: ['sent', 'him."', '+', 'The']
# 	Output_words ['Remembrall', 'glittered', 'in', 'the']
# Created sample:
# 	Scan time: 666
# 	Input words: ['Remembrall', 'glittered', 'in', 'the']
# 	Output_words ['sun', 'as', 'he', 'held']
# Created sample:
# 	Scan time: 700
# 	Input words: ['"Give', 'that', 'here,', 'Malfoy,"']
# 	Output_words ['said', 'Harry', 'quietly.', 'Everyone']
# Created sample:
# 	Scan time: 702
# 	Input words: ['said', 'Harry', 'quietly.', 'Everyone']
# 	Output_words ['stopped', 'talking', 'to', 'watch.']
# Created sample:
# 	Scan time: 704
# 	Input words: ['stopped', 'talking', 'to', 'watch.']
# 	Output_words ['+', 'Malfoy', 'smiled', 'nastily.']
# Created sample:
# 	Scan time: 706
# 	Input words: ['+', 'Malfoy', 'smiled', 'nastily.']
# 	Output_words ['"I', 'think', "I'll", 'leave']
# Created sample:
# 	Scan time: 708
# 	Input words: ['"I', 'think', "I'll", 'leave']
# 	Output_words ['it', 'somewhere', 'for', 'Longbottom']
# Created sample:
# 	Scan time: 710
# 	Input words: ['it', 'somewhere', 'for', 'Longbottom']
# 	Output_words ['to', 'find', '--', 'how']
# Created sample:
# 	Scan time: 712
# 	Input words: ['to', 'find', '--', 'how']
# 	Output_words ['about', '--', 'up', 'a']
# Created sample:
# 	Scan time: 714
# 	Input words: ['about', '--', 'up', 'a']
# 	Output_words ['tree?"', '+', '"Give', 'it']
# Created sample:
# 	Scan time: 716
# 	Input words: ['tree?"', '+', '"Give', 'it']
# 	Output_words ['@here!"', 'Harry', 'yelled,', 'but']
# Created sample:
# 	Scan time: 718
# 	Input words: ['@here!"', 'Harry', 'yelled,', 'but']
# 	Output_words ['Malfoy', 'had', 'leapt', 'onto']
# Created sample:
# 	Scan time: 720
# 	Input words: ['Malfoy', 'had', 'leapt', 'onto']
# 	Output_words ['his', 'broomstick', 'and', 'taken']
# Created sample:
# 	Scan time: 722
# 	Input words: ['his', 'broomstick', 'and', 'taken']
# 	Output_words ['off.', 'He', "hadn't", 'been']
# Created sample:
# 	Scan time: 724
# 	Input words: ['off.', 'He', "hadn't", 'been']
# 	Output_words ['lying,', 'he', '@could', 'fly']
# Created sample:
# 	Scan time: 726
# 	Input words: ['lying,', 'he', '@could', 'fly']
# 	Output_words ['well.', 'Hovering', 'level', 'with']
# Created sample:
# 	Scan time: 728
# 	Input words: ['well.', 'Hovering', 'level', 'with']
# 	Output_words ['the', 'topmost', 'branches', 'of']
# Created sample:
# 	Scan time: 730
# 	Input words: ['the', 'topmost', 'branches', 'of']
# 	Output_words ['an', 'oak', 'he', 'called,']
# Created sample:
# 	Scan time: 732
# 	Input words: ['an', 'oak', 'he', 'called,']
# 	Output_words ['"Come', 'and', 'get', 'it,']
# Created sample:
# 	Scan time: 734
# 	Input words: ['"Come', 'and', 'get', 'it,']
# 	Output_words ['Potter!"', '+', 'Harry', 'grabbed']
# Created sample:
# 	Scan time: 736
# 	Input words: ['Potter!"', '+', 'Harry', 'grabbed']
# 	Output_words ['his', 'broom.', '+', '@"No!"']
# Created sample:
# 	Scan time: 738
# 	Input words: ['his', 'broom.', '+', '@"No!"']
# 	Output_words ['shouted', 'Hermione', 'Granger.', '"Madam']
# Created sample:
# 	Scan time: 740
# 	Input words: ['shouted', 'Hermione', 'Granger.', '"Madam']
# 	Output_words ['Hooch', 'told', 'us', 'not']
# Created sample:
# 	Scan time: 742
# 	Input words: ['Hooch', 'told', 'us', 'not']
# 	Output_words ['to', 'move', '--', "you'll"]
# Created sample:
# 	Scan time: 744
# 	Input words: ['to', 'move', '--', "you'll"]
# 	Output_words ['get', 'us', 'all', 'into']
# Created sample:
# 	Scan time: 746
# 	Input words: ['get', 'us', 'all', 'into']
# 	Output_words ['trouble."', '+', 'Harry', 'ignored']
# Created sample:
# 	Scan time: 748
# 	Input words: ['trouble."', '+', 'Harry', 'ignored']
# 	Output_words ['her.', 'Blood', 'was', 'pounding']
# Created sample:
# 	Scan time: 750
# 	Input words: ['her.', 'Blood', 'was', 'pounding']
# 	Output_words ['in', 'his', 'ears.', 'He']
# Created sample:
# 	Scan time: 752
# 	Input words: ['in', 'his', 'ears.', 'He']
# 	Output_words ['mounted', 'the', 'broom', 'and']
# Created sample:
# 	Scan time: 754
# 	Input words: ['mounted', 'the', 'broom', 'and']
# 	Output_words ['kicked', 'hard', 'against', 'the']
# Created sample:
# 	Scan time: 756
# 	Input words: ['kicked', 'hard', 'against', 'the']
# 	Output_words ['ground', 'and', 'up,', 'up']
# Created sample:
# 	Scan time: 758
# 	Input words: ['ground', 'and', 'up,', 'up']
# 	Output_words ['he', 'soared;', 'air', 'rushed']
# Created sample:
# 	Scan time: 760
# 	Input words: ['he', 'soared;', 'air', 'rushed']
# 	Output_words ['through', 'his', 'hair,', 'and']
# Created sample:
# 	Scan time: 762
# 	Input words: ['through', 'his', 'hair,', 'and']
# 	Output_words ['his', 'robes', 'whipped', 'out']
# Created sample:
# 	Scan time: 764
# 	Input words: ['his', 'robes', 'whipped', 'out']
# 	Output_words ['behind', 'him', '--', 'and']
# Created sample:
# 	Scan time: 766
# 	Input words: ['behind', 'him', '--', 'and']
# 	Output_words ['in', 'a', 'rush', 'of']
# Created sample:
# 	Scan time: 768
# 	Input words: ['in', 'a', 'rush', 'of']
# 	Output_words ['fierce', 'joy', 'he', 'realized']
# Created sample:
# 	Scan time: 770
# 	Input words: ['fierce', 'joy', 'he', 'realized']
# 	Output_words ["he'd", 'found', 'something', 'he']
# Created sample:
# 	Scan time: 772
# 	Input words: ["he'd", 'found', 'something', 'he']
# 	Output_words ['could', 'do', 'without', 'being']
# Created sample:
# 	Scan time: 774
# 	Input words: ['could', 'do', 'without', 'being']
# 	Output_words ['taught', '--', 'this', 'was']
# Created sample:
# 	Scan time: 776
# 	Input words: ['taught', '--', 'this', 'was']
# 	Output_words ['easy,', 'this', 'was', '@wonderful.']
# Created sample:
# 	Scan time: 778
# 	Input words: ['easy,', 'this', 'was', '@wonderful.']
# 	Output_words ['He', 'pulled', 'his', 'broomstick']
# Created sample:
# 	Scan time: 780
# 	Input words: ['He', 'pulled', 'his', 'broomstick']
# 	Output_words ['up', 'a', 'little', 'to']
# Created sample:
# 	Scan time: 782
# 	Input words: ['up', 'a', 'little', 'to']
# 	Output_words ['take', 'it', 'even', 'higher,']
# Created sample:
# 	Scan time: 784
# 	Input words: ['take', 'it', 'even', 'higher,']
# 	Output_words ['and', 'heard', 'screams', 'and']
# Created sample:
# 	Scan time: 786
# 	Input words: ['and', 'heard', 'screams', 'and']
# ...
# 	Output_words ['the', 'third', 'floor.', 'And']
# Created sample:
# 	Scan time: 2448
# 	Input words: ['the', 'third', 'floor.', 'And']
# 	Output_words ['now', 'they', 'knew', 'why']
# Created sample:
# 	Scan time: 2450
# 	Input words: ['now', 'they', 'knew', 'why']
# 	Output_words ['it', 'was', 'forbidden.', '+']
# Created sample:
# 	Scan time: 2452
# 	Input words: ['it', 'was', 'forbidden.', '+']
# 	Output_words ['They', 'were', 'looking', 'straight']
# Created sample:
# 	Scan time: 2454
# 	Input words: ['They', 'were', 'looking', 'straight']
# 	Output_words ['into', 'the', 'eyes', 'of']
# Created sample:
# 	Scan time: 2456
# 	Input words: ['into', 'the', 'eyes', 'of']
# 	Output_words ['a', 'monstrous', 'dog,', 'a']
# Created sample:
# 	Scan time: 2458
# 	Input words: ['a', 'monstrous', 'dog,', 'a']
# 	Output_words ['dog', 'that', 'filled', 'the']
# Created sample:
# 	Scan time: 2460
# 	Input words: ['dog', 'that', 'filled', 'the']
# 	Output_words ['whole', 'space', 'between', 'ceiling']
# Created sample:
# 	Scan time: 2462
# 	Input words: ['whole', 'space', 'between', 'ceiling']
# 	Output_words ['and', 'floor.', 'It', 'had']
# Created sample:
# 	Scan time: 2464
# 	Input words: ['and', 'floor.', 'It', 'had']
# 	Output_words ['three', 'heads.', 'Three', 'pairs']
# Created sample:
# 	Scan time: 2466
# 	Input words: ['three', 'heads.', 'Three', 'pairs']
# 	Output_words ['of', 'rolling,', 'mad', 'eyes;']
# Created sample:
# 	Scan time: 2468
# 	Input words: ['of', 'rolling,', 'mad', 'eyes;']
# 	Output_words ['three', 'noses,', 'twitching', 'and']
# Created sample:
# 	Scan time: 2470
# 	Input words: ['three', 'noses,', 'twitching', 'and']
# 	Output_words ['quivering', 'in', 'their', 'direction;']
# Created sample:
# 	Scan time: 2472
# 	Input words: ['quivering', 'in', 'their', 'direction;']
# 	Output_words ['three', 'drooling', 'mouths,', 'saliva']
# Created sample:
# 	Scan time: 2474
# 	Input words: ['three', 'drooling', 'mouths,', 'saliva']
# 	Output_words ['hanging', 'in', 'slippery', 'ropes']
# Created sample:
# 	Scan time: 2476
# 	Input words: ['hanging', 'in', 'slippery', 'ropes']
# 	Output_words ['from', 'yellowish', 'fangs.', '+']
# Created sample:
# 	Scan time: 2478
# 	Input words: ['from', 'yellowish', 'fangs.', '+']
# 	Output_words ['It', 'was', 'standing', 'quite']
# Created sample:
# 	Scan time: 2480
# 	Input words: ['It', 'was', 'standing', 'quite']
# 	Output_words ['still,', 'all', 'six', 'eyes']
# Created sample:
# 	Scan time: 2482
# 	Input words: ['still,', 'all', 'six', 'eyes']
# 	Output_words ['staring', 'at', 'them,', 'and']
# Created sample:
# 	Scan time: 2484
# 	Input words: ['staring', 'at', 'them,', 'and']
# 	Output_words ['Harry', 'knew', 'that', 'the']
# Created sample:
# 	Scan time: 2486
# 	Input words: ['Harry', 'knew', 'that', 'the']
# 	Output_words ['only', 'reason', 'they', "weren't"]
# Created sample:
# 	Scan time: 2488
# 	Input words: ['only', 'reason', 'they', "weren't"]
# 	Output_words ['already', 'dead', 'was', 'that']
# Created sample:
# 	Scan time: 2490
# 	Input words: ['already', 'dead', 'was', 'that']
# 	Output_words ['their', 'sudden', 'appearance', 'had']
# Created sample:
# 	Scan time: 2492
# 	Input words: ['their', 'sudden', 'appearance', 'had']
# 	Output_words ['taken', 'it', 'by', 'surprise,']
# Created sample:
# 	Scan time: 2494
# 	Input words: ['taken', 'it', 'by', 'surprise,']
# 	Output_words ['but', 'it', 'was', 'quickly']
# Created sample:
# 	Scan time: 2496
# 	Input words: ['but', 'it', 'was', 'quickly']
# 	Output_words ['getting', 'over', 'that,', 'there']
# Created sample:
# 	Scan time: 2498
# 	Input words: ['getting', 'over', 'that,', 'there']
# 	Output_words ['was', 'no', 'mistaking', 'what']
# Created sample:
# 	Scan time: 2500
# 	Input words: ['was', 'no', 'mistaking', 'what']
# 	Output_words ['those', 'thunderous', 'growls', 'meant.']
# Created sample:
# 	Scan time: 2502
# 	Input words: ['those', 'thunderous', 'growls', 'meant.']
# 	Output_words ['+', 'Harry', 'groped', 'for']
# Created sample:
# 	Scan time: 2504
# 	Input words: ['+', 'Harry', 'groped', 'for']
# 	Output_words ['the', 'doorknob', '--', 'between']
# Created sample:
# 	Scan time: 2506
# 	Input words: ['the', 'doorknob', '--', 'between']
# 	Output_words ['Filch', 'and', 'death,', "he'd"]
# Created sample:
# 	Scan time: 2508
# 	Input words: ['Filch', 'and', 'death,', "he'd"]
# 	Output_words ['take', 'Filch.', '+', 'They']
# Created sample:
# 	Scan time: 2510
# 	Input words: ['take', 'Filch.', '+', 'They']
# 	Output_words ['fell', 'backward', '--', 'Harry']
# Created sample:
# 	Scan time: 2512
# 	Input words: ['fell', 'backward', '--', 'Harry']
# 	Output_words ['slammed', 'the', 'door', 'shut,']
# Created sample:
# 	Scan time: 2514
# 	Input words: ['slammed', 'the', 'door', 'shut,']
# 	Output_words ['and', 'they', 'ran,', 'they']
# Created sample:
# 	Scan time: 2516
# 	Input words: ['and', 'they', 'ran,', 'they']
# 	Output_words ['almost', 'flew,', 'back', 'down']
# Created sample:
# 	Scan time: 2518
# 	Input words: ['almost', 'flew,', 'back', 'down']
# 	Output_words ['the', 'corridor.', 'Filch', 'must']
# Created sample:
# 	Scan time: 2520
# 	Input words: ['the', 'corridor.', 'Filch', 'must']
# 	Output_words ['have', 'hurried', 'off', 'to']
# Created sample:
# 	Scan time: 2522
# 	Input words: ['have', 'hurried', 'off', 'to']
# 	Output_words ['look', 'for', 'them', 'somewhere']
# Created sample:
# 	Scan time: 2524
# 	Input words: ['look', 'for', 'them', 'somewhere']
# 	Output_words ['else,', 'because', 'they', "didn't"]
# Created sample:
# 	Scan time: 2526
# 	Input words: ['else,', 'because', 'they', "didn't"]
# 	Output_words ['see', 'him', 'anywhere,', 'but']
# Created sample:
# 	Scan time: 2528
# 	Input words: ['see', 'him', 'anywhere,', 'but']
# 	Output_words ['they', 'hardly', 'cared', '--']
# Created sample:
# 	Scan time: 2530
# 	Input words: ['they', 'hardly', 'cared', '--']
# 	Output_words ['all', 'they', 'wanted', 'to']
# Created sample:
# 	Scan time: 2532
# 	Input words: ['all', 'they', 'wanted', 'to']
# 	Output_words ['do', 'was', 'put', 'as']
# Created sample:
# 	Scan time: 2534
# 	Input words: ['do', 'was', 'put', 'as']
# 	Output_words ['much', 'space', 'as', 'possible']
# Created sample:
# 	Scan time: 2536
# 	Input words: ['much', 'space', 'as', 'possible']
# 	Output_words ['between', 'them', 'and', 'that']
# Created sample:
# 	Scan time: 2538
# 	Input words: ['between', 'them', 'and', 'that']
# 	Output_words ['monster.', 'They', "didn't", 'stop']
# Created sample:
# 	Scan time: 2540
# 	Input words: ['monster.', 'They', "didn't", 'stop']
# 	Output_words ['running', 'until', 'they', 'reached']
# Created sample:
# 	Scan time: 2542
# 	Input words: ['running', 'until', 'they', 'reached']
# 	Output_words ['the', 'portrait', 'of', 'the']
# Created sample:
# 	Scan time: 2544
# 	Input words: ['the', 'portrait', 'of', 'the']
# 	Output_words ['Fat', 'Lady', 'on', 'the']
# Created sample:
# 	Scan time: 2546
# 	Input words: ['Fat', 'Lady', 'on', 'the']
# 	Output_words ['seventh', 'floor.', '+', '"Where']
# Created sample:
# 	Scan time: 2548
# 	Input words: ['seventh', 'floor.', '+', '"Where']
# 	Output_words ['on', 'earth', 'have', 'you']
# Created sample:
# 	Scan time: 2550
# 	Input words: ['on', 'earth', 'have', 'you']
# 	Output_words ['all', 'been?"', 'she', 'asked,']
# Created sample:
# 	Scan time: 2552
# 	Input words: ['all', 'been?"', 'she', 'asked,']
# 	Output_words ['looking', 'at', 'their', 'bathrobes']
# Created sample:
# 	Scan time: 2554
# 	Input words: ['looking', 'at', 'their', 'bathrobes']
# 	Output_words ['hanging', 'off', 'their', 'shoulders']
# Created sample:
# 	Scan time: 2556
# 	Input words: ['hanging', 'off', 'their', 'shoulders']
# 	Output_words ['and', 'their', 'flushed,', 'sweaty']
# Created sample:
# 	Scan time: 2558
# 	Input words: ['and', 'their', 'flushed,', 'sweaty']
# 	Output_words ['faces.', '+', '"Never', 'mind']
# Created sample:
# 	Scan time: 2560
# 	Input words: ['faces.', '+', '"Never', 'mind']
# 	Output_words ['that', '--', 'pig', 'snout,']
# Created sample:
# 	Scan time: 2562
# 	Input words: ['that', '--', 'pig', 'snout,']
# 	Output_words ['pig', 'snout,"', 'panted', 'Harry,']
# Created sample:
# 	Scan time: 2564
# 	Input words: ['pig', 'snout,"', 'panted', 'Harry,']
# 	Output_words ['and', 'the', 'portrait', 'swung']
# Created sample:
# 	Scan time: 2566
# 	Input words: ['and', 'the', 'portrait', 'swung']
# 	Output_words ['forward.', 'They', 'scrambled', 'into']
# Created sample:
# 	Scan time: 2568
# 	Input words: ['forward.', 'They', 'scrambled', 'into']
# 	Output_words ['the', 'common', 'room', 'and']
# Created sample:
# 	Scan time: 2570
# 	Input words: ['the', 'common', 'room', 'and']
# 	Output_words ['collapsed,', 'trembling,', 'into', 'armchairs.']
# Created sample:
# 	Scan time: 2572
# 	Input words: ['collapsed,', 'trembling,', 'into', 'armchairs.']
# 	Output_words ['+', 'It', 'was', 'a']
# Created sample:
# 	Scan time: 2574
# 	Input words: ['+', 'It', 'was', 'a']
# 	Output_words ['while', 'before', 'any', 'of']
# Created sample:
# 	Scan time: 2576
# 	Input words: ['while', 'before', 'any', 'of']
# 	Output_words ['them', 'said', 'anything.', 'Neville,']
# Created sample:
# 	Scan time: 2578
# 	Input words: ['them', 'said', 'anything.', 'Neville,']
# 	Output_words ['indeed,', 'looked', 'as', 'if']
# Created sample:
# 	Scan time: 2580
# 	Input words: ['indeed,', 'looked', 'as', 'if']
# 	Output_words ["he'd", 'never', 'speak', 'again.']
# Created sample:
# 	Scan time: 2582
# 	Input words: ["he'd", 'never', 'speak', 'again.']
# 	Output_words ['+', '"What', 'do', 'they']
# Created sample:
# 	Scan time: 2584
# 	Input words: ['+', '"What', 'do', 'they']
# 	Output_words ['think', "they're", 'doing,', 'keeping']
# Created sample:
# 	Scan time: 2586
# 	Input words: ['think', "they're", 'doing,', 'keeping']
# 	Output_words ['a', 'thing', 'like', 'that']
# Created sample:
# 	Scan time: 2588
# 	Input words: ['a', 'thing', 'like', 'that']
# 	Output_words ['locked', 'up', 'in', 'a']
# Created sample:
# 	Scan time: 2590
# 	Input words: ['locked', 'up', 'in', 'a']
# 	Output_words ['school?"', 'said', 'Ron', 'finally.']
# Created sample:
# 	Scan time: 2592
# 	Input words: ['school?"', 'said', 'Ron', 'finally.']
# 	Output_words ['"If', 'any', 'dog', 'needs']
# Created sample:
# 	Scan time: 2594
# 	Input words: ['"If', 'any', 'dog', 'needs']
# 	Output_words ['exercise,', 'that', 'one', 'does."']
# Created sample:
# 	Scan time: 2596
# 	Input words: ['exercise,', 'that', 'one', 'does."']
# 	Output_words ['+', 'Hermione', 'had', 'got']
# Created sample:
# 	Scan time: 2598
# 	Input words: ['+', 'Hermione', 'had', 'got']
# 	Output_words ['both', 'her', 'breath', 'and']
# Created sample:
# 	Scan time: 2600
# 	Input words: ['both', 'her', 'breath', 'and']
# 	Output_words ['her', 'bad', 'temper', 'back']
# Created sample:
# 	Scan time: 2602
# 	Input words: ['her', 'bad', 'temper', 'back']
# 	Output_words ['again.', '+', '"You', "don't"]
# Created sample:
# 	Scan time: 2604
# 	Input words: ['again.', '+', '"You', "don't"]
# 	Output_words ['use', 'your', 'eyes,', 'any']
# Created sample:
# 	Scan time: 2606
# 	Input words: ['use', 'your', 'eyes,', 'any']
# 	Output_words ['of', 'you,', 'do', 'you?"']
# Created sample:
# 	Scan time: 2608
# 	Input words: ['of', 'you,', 'do', 'you?"']
# 	Output_words ['she', 'snapped.', '"Didn\'t', 'you']
# Created sample:
# 	Scan time: 2610
# 	Input words: ['she', 'snapped.', '"Didn\'t', 'you']
# 	Output_words ['see', 'what', 'it', 'was']
# Created sample:
# 	Scan time: 2612
# 	Input words: ['see', 'what', 'it', 'was']
# 	Output_words ['standing', 'on?"', '+', '"The']
# Created sample:
# 	Scan time: 2614
# 	Input words: ['standing', 'on?"', '+', '"The']
# 	Output_words ['floor?"', 'Harry', 'suggested.', '"I']
# Created sample:
# 	Scan time: 2616
# 	Input words: ['floor?"', 'Harry', 'suggested.', '"I']
# 	Output_words ["wasn't", 'looking', 'at', 'its']
# Created sample:
# 	Scan time: 2618
# 	Input words: ["wasn't", 'looking', 'at', 'its']
# 	Output_words ['feet,', 'I', 'was', 'too']
# Created sample:
# 	Scan time: 2620
# 	Input words: ['feet,', 'I', 'was', 'too']
# 	Output_words ['busy', 'with', 'its', 'heads."']
# Created sample:
# 	Scan time: 2622
# 	Input words: ['busy', 'with', 'its', 'heads."']
# 	Output_words ['+', '"No,', '@not', 'the']
# Created sample:
# 	Scan time: 2624
# 	Input words: ['+', '"No,', '@not', 'the']
# 	Output_words ['floor.', 'It', 'was', 'standing']
# Created sample:
# 	Scan time: 2626
# 	Input words: ['floor.', 'It', 'was', 'standing']
# 	Output_words ['on', 'a', 'trapdoor.', "It's"]
# Created sample:
# 	Scan time: 2628
# 	Input words: ['on', 'a', 'trapdoor.', "It's"]
# 	Output_words ['obviously', 'guarding', 'something."', '+']
# Created sample:
# 	Scan time: 2630
# 	Input words: ['obviously', 'guarding', 'something."', '+']
# 	Output_words ['She', 'stood', 'up,', 'glaring']
# Created sample:
# 	Scan time: 2632
# 	Input words: ['She', 'stood', 'up,', 'glaring']
# 	Output_words ['at', 'them.', '+', '"I']
# Created sample:
# 	Scan time: 2634
# 	Input words: ['at', 'them.', '+', '"I']
# 	Output_words ['hope', "you're", 'pleased', 'with']
# Created sample:
# 	Scan time: 2636
# 	Input words: ['hope', "you're", 'pleased', 'with']
# 	Output_words ['yourselves.', 'We', 'could', 'all']
# Created sample:
# 	Scan time: 2638
# 	Input words: ['yourselves.', 'We', 'could', 'all']
# 	Output_words ['have', 'been', 'killed', '--']
# Created sample:
# 	Scan time: 2640
# 	Input words: ['have', 'been', 'killed', '--']
# 	Output_words ['or', 'worse,', 'expelled.', 'Now,']
# Created sample:
# 	Scan time: 2642
# 	Input words: ['or', 'worse,', 'expelled.', 'Now,']
# 	Output_words ['if', 'you', "don't", 'mind,']
# Created sample:
# 	Scan time: 2644
# 	Input words: ['if', 'you', "don't", 'mind,']
# 	Output_words ["I'm", 'going', 'to', 'bed."']
# Created sample:
# 	Scan time: 2646
# 	Input words: ["I'm", 'going', 'to', 'bed."']
# 	Output_words ['+', 'Ron', 'stared', 'after']
# Created sample:
# 	Scan time: 2648
# 	Input words: ['+', 'Ron', 'stared', 'after']
# 	Output_words ['her,', 'his', 'mouth', 'open.']
# Created sample:
# 	Scan time: 2650
# 	Input words: ['her,', 'his', 'mouth', 'open.']
# 	Output_words ['"No,', 'we', "don't", 'mind,"']
# Created sample:
# 	Scan time: 2652
# 	Input words: ['"No,', 'we', "don't", 'mind,"']
# 	Output_words ['he', 'said.', '"You\'d', 'think']
# Created sample:
# 	Scan time: 2654
# 	Input words: ['he', 'said.', '"You\'d', 'think']
# 	Output_words ['we', 'dragged', 'her', 'along,']
# Created sample:
# 	Scan time: 2656
# 	Input words: ['we', 'dragged', 'her', 'along,']
# 	Output_words ["wouldn't", 'you?"', '+', 'But']
# Created sample:
# 	Scan time: 2658
# 	Input words: ["wouldn't", 'you?"', '+', 'But']
# 	Output_words ['Hermione', 'had', 'given', 'Harry']
# Created sample:
# 	Scan time: 2660
# 	Input words: ['Hermione', 'had', 'given', 'Harry']
# 	Output_words ['something', 'else', 'to', 'think']
# Created sample:
# 	Scan time: 2662
# 	Input words: ['something', 'else', 'to', 'think']
# 	Output_words ['about', 'as', 'he', 'climbed']
# Created sample:
# 	Scan time: 2664
# 	Input words: ['about', 'as', 'he', 'climbed']
# 	Output_words ['back', 'into', 'bed.', 'The']
# Created sample:
# 	Scan time: 2666
# 	Input words: ['back', 'into', 'bed.', 'The']
# 	Output_words ['dog', 'was', 'guarding', 'something.']
# Created sample:
# 	Scan time: 2668
# 	Input words: ['dog', 'was', 'guarding', 'something.']
# 	Output_words ['.', '.', '.', 'What']
# Created sample:
# 	Scan time: 2670
# 	Input words: ['.', '.', '.', 'What']
# 	Output_words ['had', 'Hagrid', 'said?', 'Gringotts']
# Created sample:
# 	Scan time: 2672
# 	Input words: ['had', 'Hagrid', 'said?', 'Gringotts']
# 	Output_words ['was', 'the', 'safest', 'place']
# Created sample:
# 	Scan time: 2674
# 	Input words: ['was', 'the', 'safest', 'place']
# 	Output_words ['in', 'the', 'world', 'for']
# Created sample:
# 	Scan time: 2676
# 	Input words: ['in', 'the', 'world', 'for']
# 	Output_words ['something', 'you', 'wanted', 'to']
# Created sample:
# 	Scan time: 2678
# 	Input words: ['something', 'you', 'wanted', 'to']
# 	Output_words ['hide', '--', 'except', 'perhaps']
# Created sample:
# 	Scan time: 2680
# 	Input words: ['hide', '--', 'except', 'perhaps']
# 	Output_words ['Hogwarts.', '+', 'It', 'looked']
# Created sample:
# 	Scan time: 2682
# 	Input words: ['Hogwarts.', '+', 'It', 'looked']
# 	Output_words ['as', 'though', 'Harry', 'had']
# Created sample:
# 	Scan time: 2684
# 	Input words: ['as', 'though', 'Harry', 'had']
# 	Output_words ['found', 'out', 'where', 'the']
# Created sample:
# 	Scan time: 2686
# 	Input words: ['found', 'out', 'where', 'the']
# 	Output_words ['grubby', 'little', 'package', 'from']
# Created sample:
# 	Scan time: 2688
# 	Input words: ['grubby', 'little', 'package', 'from']
# 	Output_words ['vault', 'seven', 'hundred', 'and']
# Total number of samples: 1287

# %% [markdown]
# ## Initialize model

# %%
class LinearModel(nn.Module):
    def __init__(self, num_features, num_outputs):
        super(LinearModel, self).__init__()
        self.linear = nn.Linear(num_features, num_outputs)

    def forward(self, x):
        out = self.linear(x)
        return out

# %% [markdown]
# ## Build samples and separate into folds

# %%
subject_0_samples = subjects_samples[0] #only using the first subjects samples currently
fmri_size = subject_0_samples[0].get_input_voxels().shape[1]
word_feature_size = subject_0_samples[0].get_input_word_features().shape[1]
samples = np.zeros((len(subject_0_samples), (fmri_size) + (word_feature_size * 8)))
#samples = np.zeros((len(subject_0_samples), word_feature_size * 8))
for i in range(len(subject_0_samples)):
    samples[i, :fmri_size] = subject_0_samples[i].get_input_voxels()[2] #get feature 6 seconds after reading 4 words
#     samples[i, fmri_size: fmri_size*2] = subject_0_samples[i].get_output_voxels()[2] #get feature 6 seconds after reading next 4 words
    samples[i, fmri_size:fmri_size + word_feature_size*4] = subject_0_samples[i].get_input_word_features().flatten()
#     samples[i, word_feature_size*4:] = np.sum(subject_0_samples[i].get_output_word_features(), axis=0)
    samples[i, fmri_size + word_feature_size*4:] = subject_0_samples[i].get_output_word_features().flatten()

# %%
NUM_FOLDS = 3
np.random.shuffle(samples) #shuffles rows
print(samples.shape)
folds = np.array(np.split(samples, NUM_FOLDS))
print(folds.shape)
# Out:
# (1287, 43333)
# (3, 429, 43333)

# %% [markdown]
# ## Train model

# %%
#performs stochastic gradient descent for num_epoch epochs
def train_model(model, samples, num_features, num_outputs, alpha=1e-7, momentum=0.9, num_epochs=50):
    print("Training for ", num_epochs, " epochs:")
    optimizer = torch.optim.SGD(model.parameters(), lr=alpha, momentum=momentum)
    loss_fn = nn.MSELoss()
    for epoch in range(num_epochs):
        epoch_loss = 0
        #randomly shuffle samples 
        np.random.shuffle(samples)
        for sample in samples:
            optimizer.zero_grad()
            x = torch.tensor(sample[:num_features]).float().to(device)
            y = torch.tensor(sample[num_features:]).float().to(device)
            pred = model(x)
            loss = loss_fn(pred, y)
            loss.backward()
            epoch_loss += loss.item()
            optimizer.step()
        if epoch % 1 == 0:
            epoch_accuracy = get_accuracy(model, samples, num_features, num_outputs)
            print("\tEpoch: ", epoch, ", Train Loss: ", epoch_loss, ", Train Accuracy: ", epoch_accuracy)
    epoch_accuracy = get_accuracy(model, samples, num_features, num_outputs)
    print("\tEpoch: ", epoch, ", Train Loss: ", epoch_loss, ", Train Accuracy: ", epoch_accuracy)

# %%
#gets the model accuracy by getting the prediction for a sample and seeing 
#if it closer to the labels of that sample or another randomly selected sample
def get_accuracy(model, samples, num_features, num_outputs):
    correct = 0
    for sample in samples:
        #gets the input and labels from current sample
        correct_x = torch.tensor(sample[:num_features]).float().to(device)
        correct_labels = torch.tensor(sample[num_features:]).float().to(device)
        #gets labels from a random sample
        rand = random.randint(0, samples.shape[0]-1)
        random_labels = torch.tensor(samples[rand,num_features:]).float().to(device)
        #gets prediction on current sample and computes euclidean distances from both correct and random labels
        pred = model(correct_x)
        correct_distance = torch.linalg.norm(correct_labels - pred)
        #print("correct distance: ", str(correct_distance))
        random_distance = torch.linalg.norm(random_labels - pred)
        #print("random distance: ", str(random_distance))
        #if distance to correct labels is less than distance to random labels then the prediction is considered correct
        if correct_distance < random_distance:
            correct += 1
    return correct / samples.shape[0]

# %%
#for each fold split, creates a model and trains it on n-1 folds and then tests it on the last fold
def cross_validate(folds, num_folds, num_features, num_outputs, num_epochs=50):
    for i in range(num_folds):
        print("Fold: ", i)
        model = LinearModel(num_features, num_outputs).to(device)
        loss_fn = nn.MSELoss()
        #gets all folds except one and reshapes them into a 2d array
        train_samples = np.reshape(np.delete(folds, i, axis=0), (folds.shape[1]*(num_folds-1), folds.shape[2])) 
        test_samples = folds[i]
        train_model(model, train_samples, num_features, num_outputs, num_epochs=num_epochs)
        test_loss = 0
        for sample in test_samples:
            x = torch.tensor(sample[:num_features]).float().to(device)
            y = torch.tensor(sample[num_features:]).float().to(device)
            pred = model(x)
            loss = loss_fn(pred, y)
            test_loss += loss.item()
        test_accuracy = get_accuracy(model, test_samples, num_features, num_outputs)
        print("\tFold: ", i, ", Test Loss: ", test_loss, ", Test Accuracy: ", test_accuracy)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
cross_validate(folds, NUM_FOLDS, fmri_size + word_feature_size*4, word_feature_size*4, num_epochs=500)
# Out:
# cuda
# Fold:  0
# Training for  500  epochs:
# 	Epoch:  0 , Train Loss:  1025102.5688171387 , Train Accuracy:  0.49417249417249415
# 	Epoch:  1 , Train Loss:  110160.85584640503 , Train Accuracy:  0.5104895104895105
# 	Epoch:  2 , Train Loss:  104102.3522529602 , Train Accuracy:  0.4965034965034965
# 	Epoch:  3 , Train Loss:  91302.08600616455 , Train Accuracy:  0.48834498834498835
# 	Epoch:  4 , Train Loss:  88250.85731124878 , Train Accuracy:  0.5046620046620046
# 	Epoch:  5 , Train Loss:  79035.21173095703 , Train Accuracy:  0.47086247086247085
# 	Epoch:  6 , Train Loss:  76621.67371749878 , Train Accuracy:  0.5233100233100233
# 	Epoch:  7 , Train Loss:  72748.39073944092 , Train Accuracy:  0.5151515151515151
# 	Epoch:  8 , Train Loss:  70307.11055755615 , Train Accuracy:  0.5046620046620046
# 	Epoch:  9 , Train Loss:  69865.36672973633 , Train Accuracy:  0.479020979020979
# 	Epoch:  10 , Train Loss:  66186.27717971802 , Train Accuracy:  0.4976689976689977
# 	Epoch:  11 , Train Loss:  64394.73640060425 , Train Accuracy:  0.513986013986014
# 	Epoch:  12 , Train Loss:  63189.61474990845 , Train Accuracy:  0.5011655011655012
# 	Epoch:  13 , Train Loss:  64552.13715362549 , Train Accuracy:  0.4988344988344988
# 	Epoch:  14 , Train Loss:  62616.753772735596 , Train Accuracy:  0.5151515151515151
# 	Epoch:  15 , Train Loss:  61213.73377609253 , Train Accuracy:  0.5163170163170163
# 	Epoch:  16 , Train Loss:  59460.54405212402 , Train Accuracy:  0.5174825174825175
# 	Epoch:  17 , Train Loss:  56498.35355377197 , Train Accuracy:  0.5116550116550117
# 	Epoch:  18 , Train Loss:  56175.77793884277 , Train Accuracy:  0.49067599067599066
# 	Epoch:  19 , Train Loss:  55395.647064208984 , Train Accuracy:  0.48717948717948717
# 	Epoch:  20 , Train Loss:  61622.28062438965 , Train Accuracy:  0.5058275058275058
# 	Epoch:  21 , Train Loss:  53634.50848388672 , Train Accuracy:  0.5163170163170163
# 	Epoch:  22 , Train Loss:  53495.87385559082 , Train Accuracy:  0.4988344988344988
